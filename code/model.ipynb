# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv('X_train.csv',)
X_train
# Out:
#      Unnamed: 0  Year  CNT  CNTRYID    CNTSCHID    CNTSTUID   CYC  NatCen  \
# 0        384002  2022  NLD    528.0  52800132.0  52801144.0  08MS   52800
# 1       1118072  2018  QAZ     31.0   3100106.0   3100424.0  07MS    3100
# 2        845454  2018  FRA    250.0  25000010.0  25005207.0  07MS   25000
# 3       1728613  2015  QES    971.0  97100240.0  97127584.0  06MS   72400
# 4       1083243  2018  PHL    608.0  60800071.0  60802698.0  07MS   60800
# ..          ...   ...  ...      ...         ...         ...   ...     ...
# 995      334061  2022  LTU    440.0  44000122.0  44006126.0  08MS   44000
# 996      104603  2022  CAN    124.0  12400381.0  12438421.0  08MS   12400
# 997     1244480  2015  DZA     12.0   1200102.0   1203028.0  06MS    1200
# 998      741243  2018  CAN    124.0  12400794.0  12419134.0  07MS   12400
# 999      530738  2022  CHE    756.0  75600172.0  75601751.0  08MS   75600
#
#      STRATUM  SUBNATIO  ...  science_q10_total_timing  \
# ...
